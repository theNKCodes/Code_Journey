# %%
actual= [5,7,8,9]
calculate = [5,6,7,9]
for i in range(4):
  sum += abs(actual - calculate)
sum = len(actual)
sum
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-8594140e619c> in <cell line: 3>()
#       2 calculate = [5,6,7,9]
#       3 for i in range(4):
# ----> 4   sum += abs(actual - calculate)
#       5 sum = len(actual)
#       6 sum
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
