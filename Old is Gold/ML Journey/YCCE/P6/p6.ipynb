# %% [markdown]
# # Practical 6
# #### AIM : - Implement a neural network for MLP Digit-Classifier using TensorFlow.

# %% [markdown]
# #### Algorithms :-
#     Algorithm for Implementing an MLP Digit Classifier using TensorFlow:
#     1. Import Necessary Libraries:
#         • Import TensorFlow and other required libraries for data handling
#         and neural network building.
#     2. Load and Preprocess the Data:
#         • Load the digit dataset you intend to use (MNIST).
#         • Preprocess the data, including normalization and one-hot encoding
#         of labels.
#     3. Create the MLP Model:
#         • Initialize a Sequential model in TensorFlow.
#         • Add a Flatten layer to convert input images to a 1D vector.
#         • Add one or more Dense (fully connected) layers with activation
#         functions like ReLU.
#         • The last Dense layer should have units equal to the number of
#         classes (e.g., 10 for digits) with a softmax activation for
#         classification.
#     4. Compile the Model:
#         • Specify the optimizer (e.g., Adam), loss function (e.g., categorical
#         cross-entropy for classification), and evaluation metrics (e.g.,
#         accuracy).
#     5. Train the Model:
#         • Use the model.fit() function to train the MLP model on the training
#         data.
#         • Specify the number of epochs, batch size, and validation data if
#         needed.
#     6. Evaluate the Model:
#         • Use the model.evaluate() function to assess the model's
#         performance on a test dataset.
#         • Calculate accuracy or other relevant metrics.
#     7. Make Predictions:
#         • Use the trained model to make predictions on new, unseen data.
#     8. Visualize the Data
#         • Visualize the data for Better Understanding

# %%
#importing the libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Normalize the pixel values to be in the range [0, 1]
train_images = train_images / 255.0
test_images = test_images / 255.0

# One-hot encode the labels
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Out:
# ...
# 11490434/11490434 [==============================] - 9s 1us/step

# %%
#Creating the MLP
model = models.Sequential()

# Flatten the input data (28x28 images) to a 1D array
model.add(layers.Flatten(input_shape=(28, 28)))

# Add a fully connected hidden layer with 128 units and ReLU activation
model.add(layers.Dense(128, activation='relu'))

# Add another fully connected hidden layer with 64 units and ReLU activation
model.add(layers.Dense(64, activation='relu'))

# Add the output layer with 10 units (one for each digit) and softmax activation
model.add(layers.Dense(10, activation='softmax'))

# %%
#compling the MLP modal
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#training the modal
history=model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 9s 7ms/step - loss: 0.2755 - accuracy: 0.9227 - val_loss: 0.1299 - val_accuracy: 0.9609
# Epoch 2/10
# 938/938 [==============================] - 7s 8ms/step - loss: 0.1102 - accuracy: 0.9667 - val_loss: 0.1035 - val_accuracy: 0.9677
# Epoch 3/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0784 - accuracy: 0.9762 - val_loss: 0.0928 - val_accuracy: 0.9710
# Epoch 4/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0581 - accuracy: 0.9823 - val_loss: 0.0783 - val_accuracy: 0.9743
# Epoch 5/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0449 - accuracy: 0.9863 - val_loss: 0.0793 - val_accuracy: 0.9756
# Epoch 6/10
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0366 - accuracy: 0.9884 - val_loss: 0.0811 - val_accuracy: 0.9744
# Epoch 7/10
# ...

# %%
#Evaluating the modal
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc * 100}%')
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1027 - accuracy: 0.9734
# Test accuracy: 97.33999967575073%

# %%
# Sample training history data
training_results = history

# Access loss and accuracy data from the training history
train_loss = training_results.history['loss']
train_acc = training_results.history['accuracy']
valid_loss = training_results.history['val_loss']
valid_acc = training_results.history['val_accuracy']

#Graph
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label="Training Loss", color="g")
plt.plot(valid_loss, label="Validation Loss", color="b")
plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label="Training Accuracy", color="g")
plt.plot(valid_acc, label="Validation Accuracy", color="b")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# #### Result Analysis :-
#     The results of our machine learning models –offer valuable insights into their performance on the dataset.
#     The trained Multi-Layer Perceptron (MLP) model exhibits a remarkable
#     accuracy of 97% on the MNIST dataset, indicating its proficiency in recognizing
#     handwritten digits. This high accuracy underscores the model's capability in
#     correctly classifying the majority of digits in the test dataset, signifying its
#     effectiveness. The model demonstrates strong generalization as evidenced by
#     the close alignment of validation accuracy with the training accuracy. This
#     suggests that it does not overfit to the training data, rendering it suitable for
#     real-world applications.
#
# #### Conclusion :-
#     Hence, I Understand and Implemented the Algorithm in GOOGLE COLAB Successfully.
